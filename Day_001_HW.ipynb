# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
A.
1. Why it is important?
   The heart disease is a modern civilized disease, 
   through the data we can get indicators and prevent the occurrence of disease. 
2. Where do data come from?
   Creators: 
   Hungarian Institute of Cardiology. Budapest: Andras Janosi, M.D. 
   University Hospital, Zurich, Switzerland: William Steinbrunn, M.D. 
   University Hospital, Basel, Switzerland: Matthias Pfisterer, M.D. 
   V.A. Medical Center, Long Beach and Cleveland Clinic Foundation: Robert Detrano, M.D., Ph.D.
3.What are they?     
  all is Structured data.
4. What is our goal?
   

B. 
1. 核心問題為何?
   提升服務品質、提升治安設備、提升司機素質，讓顧客擁有在自己家裡車上的感受。
2. 資料從何而來?
   往上資料及市場調查
3. 蒐集而來的資料型態為何?
   司機的性別、年齡、年資、顧客評論分數、淨利潤、車趟數。
4. 你要回答的問題，其如何評估?
   透過觀察淨利潤及客戶評分的相對關係來觀察車隊業績的提升程度。

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def mean_squared_error(y,yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = sum((abs(y - yp))**2) / len(y)
    return mse

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 239.146
# The Mean absolute error is 12.599
